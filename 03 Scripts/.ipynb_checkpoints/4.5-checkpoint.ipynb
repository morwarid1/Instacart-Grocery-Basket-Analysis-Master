# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Question 1)  performing the consistency checks on df_prods dataframe

# %%
# Consistency Checks include: 1) Mixed data types - 2) Missing values - 3) Duplicate records

# %%
# 1) Finding and addressing mixed data types for sample data

# %%
# Create a dataframe 
df_test = pd.DataFrame()

# %%
# Create a mixed type column
df_test ['mix'] = ['a','b', 1, True]

# %%
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
# Function for dataframe contains any mixed_type columns
for col in df_test.columns.tolist():
    weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test[weird]) > 0:
            print (col)
# Out:
# mix

# %%
# changing the data type to str 
df_test['mix'] = df_test ['mix'].astype('str')

# %%
# making short form for the path 
path = r'/Users/monajafizada/Documents/DataAnalytics/Project'

# %%
# importing products csv data
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'OriginalData', 'products.csv'), index_col = False)

# %%
### 3 ) checking for mixed_type data in df_ords

# %%
# 1 ) Finding and addressing mixed data types for df_prods

# %%
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %%
df_prods.head() . #There is no mix type column
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# 2) Finding and addressing missing values in df_prods dataframe 
# product_name has 16 missing values 
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
# creating subset to view only the 16 missing values
df_nan = df_prods [df_prods ['product_name'].isnull() == True]

# %%
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
#  finding the non missing values in df_prods dataframe
df_prods_clean = df_prods [df_prods ['product_name'].isnull()== False]

# %%
df_prods_clean
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# 5               6                                       Dry Nose Oil
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 8               9                  Light Strawberry Blueberry Yogurt
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 11             12                         Chocolate Fudge Layer Cake
# 12             13                                  Saline Nasal Mist
# ...

# %%
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# 3 ) Finding and addressing  duplicates records in df_prods dataframe 
df_dups = df_prods_clean[df_prods_clean.duplicated()]

# %%
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
# number of rows in dataframe
df_prods_clean.shape
# Out:
# (49677, 5)

# %%
# deleting duplicates 
df_prods_clean_no_dups = df_prods_clean.drop_duplicates()

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %% [markdown]
# ### Question 2 ) df.describe of df_prods dataframe

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
1) # Column product_id has max of 49688 but we have 49693 rows. 
# The index start from 0, therefore there are 4 rows that should be investigated further. 
2) # Column prices  has max of 99999, which is to large for the price column. 
# looking at the price column I could estimate that there could not be a price higher than 30.

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# 5               6                                       Dry Nose Oil
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 8               9                  Light Strawberry Blueberry Yogurt
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 11             12                         Chocolate Fudge Layer Cake
# 12             13                                  Saline Nasal Mist
# ...

# %% [markdown]
# ### Question 3 ) checking for mixed_type data in df_ords dataframe

# %%
# making short form for the path 
path = r'/Users/monajafizada/Documents/DataAnalytics/Project'

# %%
# importing orders csv data
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'OriginalData', 'orders.csv'), index_col = False)

# %%
# check for mixed_type data in your df_ords dataframe 
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
for col in df_test2.columns.tolist():
    freak = (df_test2[[col]].applymap(type) != df_test2[[col]].iloc[0].apply(type)).any(axis = 1)
    if len (df_test2[freak]) > 0:
            print (col)

# %%
df_ords.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
# it looks like the column " days_since_prior_order" has float and strings in it.

# %% [markdown]
# ### Question 4 ) fixing mixed_type data of column "days_since_prior_order "

# %%
# The column " days_since_prior_order" contains mostly float and the dtypes is float, which is the right format.

# %%
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %% [markdown]
# ### Question 5 ) checking for missing values in df_ords

# %%
# checking for missing values in df_ords dataframe
df_nan2 = df_ords[df_ords['days_since_prior_order'].isnull()== True]

# %%
df_nan2.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 11   2168274        2    prior             1          2                 11
# 26   1374495        3    prior             1          1                 14
# 39   3343014        4    prior             1          6                 11
# 45   2717275        5    prior             1          3                 12
#
#     days_since_prior_order
# 0                      NaN
# 11                     NaN
# 26                     NaN
# 39                     NaN
# 45                     NaN

# %%
df_nan2.shape
# Out:
# (206209, 7)

# %%
# There are 206209 rows that are has missing values in "days_since_prior_order".

# %% [markdown]
# ### Question 6 ) addressing the missing values using an appropriate method

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
# filling the missing values with mean of the column 
# I used mean becuase i wanted to take the average of the values. 
df_ords['days_since_prior_order'].fillna(1.111484e+01, inplace=True)

# %%
# cleaning missing values
df_ords_clean = df_ords[df_ords['days_since_prior_order'].isnull() == False]

# %%
df_ords_clean.shape
# Out:
# (3421083, 7)

# %%
# we can see that all missing values are replace with the mean
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                11.11484
# 1                15.00000
# 2                21.00000
# 3                29.00000
# 4                28.00000

# %%
# we can see that all missing values are replaced with the mean
df_nan2.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 11   2168274        2    prior             1          2                 11
# 26   1374495        3    prior             1          1                 14
# 39   3343014        4    prior             1          6                 11
# 45   2717275        5    prior             1          3                 12
#
#     days_since_prior_order
# 0                 11.11484
# 11                11.11484
# 26                11.11484
# 39                11.11484
# 45                11.11484

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# ###  Question 7 ) Checking for the duplicate values of df_ords

# %%
# finding duplicate values in df_ords dataframe
df_dups1 = df_ords_clean [df_ords_clean.duplicated()]

# %%
df_dups1
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
# It looks like that df_ords does not have any duplicated Data

# %% [markdown]
# ### Question 8 ) addressing the duplicated value

# %%
# the df_ords does not have duplicated values

# %% [markdown]
# ### Question 9 ) exporting the cleaned df_prods and df_ords data as "csv" files in "Prepared Data"

# %%
# Exporting df_ords datafram as "orders_consistencycheck.csv" in "Prepared Data"
df_ords.to_csv(os.path.join(path,'02 Data', 'PreparedData', 'orders_consistencycheck.csv'))

# %%
# Exporting df_prods as "prods_consistencycheck.csv" in "Prepared Data"
df_prods.to_csv(os.path.join(path,'02 Data', 'PreparedData', 'prods_consistencycheck.csv'))
